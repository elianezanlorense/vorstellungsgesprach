# %%
# Install the Hugging Face CLI
brew install hf

# (optional) Login with your Hugging Face credentials
hf auth login

# Push your dataset files
hf upload ezanlorense/germany-ti-job . --repo-type=dataset
