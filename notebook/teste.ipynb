# %%
import sys
from pathlib import Path
print(Path.cwd())
from vorstellungsgesprach.utils import load_data, add_language_metadata,remove_duplicate_jobs
from vorstellungsgesprach import conf
from vorstellungsgesprach import models
# %cd /Users/eli/vorstellungsgesprach
from dotenv import load_dotenv
from google import genai
import os
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from google import genai
# ----> 2 from vorstellungsgesprach import conf, models
#       3
#
# ImportError: cannot import name 'models' from 'vorstellungsgesprach' (/Users/eli/vorstellungsgesprach/src/vorstellungsgesprach/__init__.py)

# %%
import sys
sys.path.append("scripts")

from models import compare_models

resultados = compare_models("Welche Jobs erfordern Erfahrung mit Machine Learning?")
