# %%
import sys
from pathlib import Path
print(Path.cwd())
from vorstellungsgesprach.utils import load_data, add_language_metadata,remove_duplicate_jobs
from vorstellungsgesprach import conf
from vorstellungsgesprach.models import compare_models
# %cd /Users/eli/vorstellungsgesprach
from dotenv import load_dotenv
from google import genai
import os
load_dotenv()
# Out:
# /Users/eli/vorstellungsgesprach/notebook
# /Users/eli/vorstellungsgesprach
# True

# %%
resultados = compare_models(
    "Welche Jobs erfordern Erfahrung mit Machine Learning?"
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 resultados = compare_models(
#       2     "Welche Jobs erfordern Erfahrung mit Machine Learning?"
#       3 )
#
# File ~/vorstellungsgesprach/src/vorstellungsgesprach/models.py:73, in compare_models(question)
#      67     return []
#      69 chroma_client = chromadb.PersistentClient(
#      70     path=str(CHROMA_PATH),
#      71 )
# ---> 73 collection = chroma_client.get_collection(
#      74     name=COLLECTION_NAME,
#      75 )
#      77 results: list[dict[str, Any]] = []
#      79 for model_name in available_models:
#
# File ~/vorstellungsgesprach/.venv/lib/python3.12/site-packages/chromadb/api/client.py:260, in Client.get_collection(self, name, embedding_function, data_loader)
#     238 @override
#     239 def get_collection(
#     240     self,
#    (...)    245     data_loader: Optional[DataLoader[Loadable]] = None,
#     246 ) -> Collection:
#     247     """Get a collection by name.
#     248
#     249     Args:
#    (...)    258         ValueError: If the embedding function conflicts with configuration.
#     259     """
# --> 260     model = self._server.get_collection(
#     261         name=name,
#     262         tenant=self.tenant,
#     263         database=self.database,
#     264     )
#     265     persisted_ef_config = model.configuration_json.get("embedding_function")
#     267     validate_embedding_function_conflict_on_get(
#     268         embedding_function, persisted_ef_config
#     269     )
#
# File ~/vorstellungsgesprach/.venv/lib/python3.12/site-packages/chromadb/api/rust.py:272, in RustBindingsAPI.get_collection(self, name, tenant, database)
#     265 @override
#     266 def get_collection(
#     267     self,
#    (...)    270     database: str = DEFAULT_DATABASE,
#     271 ) -> CollectionModel:
# --> 272     collection = self.bindings.get_collection(name, tenant, database)
#     273     return CollectionModel(
#     274         id=collection.id,
#     275         name=collection.name,
#    (...)    281         database=collection.database,
#     282     )
#
# NotFoundError: Collection [vagas_ti] does not exist
